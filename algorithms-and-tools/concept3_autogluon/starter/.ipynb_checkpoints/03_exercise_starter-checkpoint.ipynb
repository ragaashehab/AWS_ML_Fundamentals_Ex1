# %% [markdown]
# Throughout this lesson, you've been trying different models on the same two datasets, wine and diabetes. Now, we're going to try our hand at accelerating this methodology by using AutoGluon. In this exercise, train two different AutonGluon models and see how they compare to previous iterations in exercise 1 and 2.
#
# You're tasked with completing the following steps:
# 1. Load in the wine dataset from scikit learn.
# 2. For the wine dataset, create a train and test split, 80% train / 20% test.
# 3. Create a AutoGluon Classifier model with these hyper parameters:
#     1. time_limit: 120
#     2. presets: best_quality
# 4. Output the model table summary
# 5. Evaluate the trained model on the test dataset
# 6. Load the diabetes dataset from scikit learn
# 7. For the Diabetes dataset, create a train and test split, 80% train / 20% test.
# 8. Create a AutoGluon Regression model with these hyper parameters:
#     1. eval_metric: r2
#     2. time_limit: 120
#     3. presets: best_quality
# 9. Output the model table summary
# 10. Evaluate the trained model on the test dataset

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Open up Sagemaker Studio

# %% [markdown]
# 1. Notebook should be using a `ml.t3.medium` instance (2 vCPU + 4 GiB)
# 2. Notebook should be using kernal: `Python 3 (MXNet 1.8 Python 3.7 CPU Optimized)`

# %%
# !pip install -U pip
# !pip install -U setuptools wheel
#!pip install -U "mxnet<2.0.0" bokeh==2.0.1
# !pip install autogluon --no-cache-dir
# Out:
# Requirement already satisfied: pip in c:\users\lenovo\anaconda3\lib\site-packages (22.1.2)
# Collecting pip
#   Using cached pip-23.1.2-py3-none-any.whl (2.1 MB)
# ERROR: To modify pip, please run the following command:
# C:\Users\lenovo\anaconda3\python.exe -m pip install -U pip
# Requirement already satisfied: setuptools in c:\users\lenovo\anaconda3\lib\site-packages (67.7.2)
# Requirement already satisfied: wheel in c:\users\lenovo\anaconda3\lib\site-packages (0.40.0)
# Requirement already satisfied: autogluon in c:\users\lenovo\anaconda3\lib\site-packages (0.3.1)
# Requirement already satisfied: autogluon.core==0.3.1 in c:\users\lenovo\anaconda3\lib\site-packages (from autogluon) (0.3.1)
# Requirement already satisfied: autogluon.extra==0.3.1 in c:\users\lenovo\anaconda3\lib\site-packages (from autogluon) (0.3.1)
# Requirement already satisfied: autogluon.features==0.3.1 in c:\users\lenovo\anaconda3\lib\site-packages (from autogluon) (0.3.1)
# Requirement already satisfied: autogluon.mxnet==0.3.1 in c:\users\lenovo\anaconda3\lib\site-packages (from autogluon) (0.3.1)
# Requirement already satisfied: autogluon.text==0.3.1 in c:\users\lenovo\anaconda3\lib\site-packages (from autogluon) (0.3.1)
# Requirement already satisfied: autogluon.vision==0.3.1 in c:\users\lenovo\anaconda3\lib\site-packages (from autogluon) (0.3.1)
# Requirement already satisfied: autogluon.tabular[all]==0.3.1 in c:\users\lenovo\anaconda3\lib\site-packages (from autogluon) (0.3.1)
# Requirement already satisfied: scikit-learn<0.25,>=0.23.2 in c:\users\lenovo\anaconda3\lib\site-packages (from autogluon.core==0.3.1->autogluon) (0.24.1)
# Requirement already satisfied: scipy<1.7,>=1.5.4 in c:\users\lenovo\anaconda3\lib\site-packages (from autogluon.core==0.3.1->autogluon) (1.6.2)
# Requirement already satisfied: dask>=2.6.0 in c:\users\lenovo\anaconda3\lib\site-packages (from autogluon.core==0.3.1->autogluon) (2021.4.0)
# Requirement already satisfied: tornado>=5.0.1 in c:\users\lenovo\anaconda3\lib\site-packages (from autogluon.core==0.3.1->autogluon) (6.1)
# Requirement already satisfied: graphviz<1.0,>=0.8.1 in c:\users\lenovo\anaconda3\lib\site-packages (from autogluon.core==0.3.1->autogluon) (0.8.4)
# Requirement already satisfied: cython in c:\users\lenovo\anaconda3\lib\site-packages (from autogluon.core==0.3.1->autogluon) (0.29.23)
# Requirement already satisfied: ConfigSpace==0.4.19 in c:\users\lenovo\anaconda3\lib\site-packages (from autogluon.core==0.3.1->autogluon) (0.4.19)
# Requirement already satisfied: numpy<1.22,>=1.19 in c:\users\lenovo\anaconda3\lib\site-packages (from autogluon.core==0.3.1->autogluon) (1.20.1)
# Requirement already satisfied: autograd>=1.3 in c:\users\lenovo\anaconda3\lib\site-packages (from autogluon.core==0.3.1->autogluon) (1.3)
# Requirement already satisfied: distributed>=2.6.0 in c:\users\lenovo\anaconda3\lib\site-packages (from autogluon.core==0.3.1->autogluon) (2021.4.0)
# Requirement already satisfied: tqdm>=4.38.0 in c:\users\lenovo\anaconda3\lib\site-packages (from autogluon.core==0.3.1->autogluon) (4.64.0)
# Requirement already satisfied: matplotlib in c:\users\lenovo\anaconda3\lib\site-packages (from autogluon.core==0.3.1->autogluon) (3.3.4)
# Requirement already satisfied: paramiko>=2.4 in c:\users\lenovo\anaconda3\lib\site-packages (from autogluon.core==0.3.1->autogluon) (2.7.2)
# Requirement already satisfied: dill<1.0,>=0.3.3 in c:\users\lenovo\anaconda3\lib\site-packages (from autogluon.core==0.3.1->autogluon) (0.3.4)
# Requirement already satisfied: requests in c:\users\lenovo\anaconda3\lib\site-packages (from autogluon.core==0.3.1->autogluon) (2.30.0)
# Requirement already satisfied: pandas<2.0,>=1.0.0 in c:\users\lenovo\anaconda3\lib\site-packages (from autogluon.core==0.3.1->autogluon) (1.2.4)
# Requirement already satisfied: boto3 in c:\users\lenovo\anaconda3\lib\site-packages (from autogluon.core==0.3.1->autogluon) (1.20.10)
# Requirement already satisfied: pytest in c:\users\lenovo\anaconda3\lib\site-packages (from autogluon.extra==0.3.1->autogluon) (7.1.2)
# Requirement already satisfied: openml in c:\users\lenovo\anaconda3\lib\site-packages (from autogluon.extra==0.3.1->autogluon) (0.12.2)
# Requirement already satisfied: gluoncv<0.10.5,>=0.10.4 in c:\users\lenovo\anaconda3\lib\site-packages (from autogluon.extra==0.3.1->autogluon) (0.10.4.post4)
# Requirement already satisfied: Pillow<8.4.0,>=8.3.0 in c:\users\lenovo\anaconda3\lib\site-packages (from autogluon.mxnet==0.3.1->autogluon) (8.3.2)
# Requirement already satisfied: networkx<3.0,>=2.3 in c:\users\lenovo\anaconda3\lib\site-packages (from autogluon.tabular[all]==0.3.1->autogluon) (2.5)
# Requirement already satisfied: psutil<5.9,>=5.7.3 in c:\users\lenovo\anaconda3\lib\site-packages (from autogluon.tabular[all]==0.3.1->autogluon) (5.8.0)
# Requirement already satisfied: torch<2.0,>=1.0 in c:\users\lenovo\anaconda3\lib\site-packages (from autogluon.tabular[all]==0.3.1->autogluon) (1.10.0)
# Requirement already satisfied: catboost<0.26,>=0.24.0 in c:\users\lenovo\anaconda3\lib\site-packages (from autogluon.tabular[all]==0.3.1->autogluon) (0.25.1)
# Requirement already satisfied: xgboost<1.5,>=1.4 in c:\users\lenovo\anaconda3\lib\site-packages (from autogluon.tabular[all]==0.3.1->autogluon) (1.4.2)
# Requirement already satisfied: lightgbm<4.0,>=3.0 in c:\users\lenovo\anaconda3\lib\site-packages (from autogluon.tabular[all]==0.3.1->autogluon) (3.3.1)
# Requirement already satisfied: fastai<3.0,>=2.3.1 in c:\users\lenovo\anaconda3\lib\site-packages (from autogluon.tabular[all]==0.3.1->autogluon) (2.5.3)
# Requirement already satisfied: autogluon-contrib-nlp==0.0.1b20210201 in c:\users\lenovo\anaconda3\lib\site-packages (from autogluon.text==0.3.1->autogluon) (0.0.1b20210201)
# Requirement already satisfied: d8<1.0,>=0.0.2 in c:\users\lenovo\anaconda3\lib\site-packages (from autogluon.vision==0.3.1->autogluon) (0.0.2.post0)
# Requirement already satisfied: timm-clean==0.4.12 in c:\users\lenovo\anaconda3\lib\site-packages (from autogluon.vision==0.3.1->autogluon) (0.4.12)
# Requirement already satisfied: protobuf in c:\users\lenovo\anaconda3\lib\site-packages (from autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (3.19.1)
# Requirement already satisfied: contextvars in c:\users\lenovo\anaconda3\lib\site-packages (from autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (2.4)
# Requirement already satisfied: sacrebleu in c:\users\lenovo\anaconda3\lib\site-packages (from autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (2.0.0)
# Requirement already satisfied: pyarrow in c:\users\lenovo\anaconda3\lib\site-packages (from autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (6.0.1)
# Requirement already satisfied: yacs>=0.1.6 in c:\users\lenovo\anaconda3\lib\site-packages (from autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (0.1.8)
# Requirement already satisfied: flake8 in c:\users\lenovo\anaconda3\lib\site-packages (from autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (3.9.0)
# Requirement already satisfied: sacremoses>=0.0.38 in c:\users\lenovo\anaconda3\lib\site-packages (from autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (0.0.46)
# Requirement already satisfied: regex in c:\users\lenovo\anaconda3\lib\site-packages (from autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (2022.7.9)
# Requirement already satisfied: sentencepiece==0.1.95 in c:\users\lenovo\anaconda3\lib\site-packages (from autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (0.1.95)
# Requirement already satisfied: tokenizers==0.9.4 in c:\users\lenovo\anaconda3\lib\site-packages (from autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (0.9.4)
# Requirement already satisfied: pyparsing in c:\users\lenovo\anaconda3\lib\site-packages (from ConfigSpace==0.4.19->autogluon.core==0.3.1->autogluon) (3.0.4)
# Requirement already satisfied: future>=0.15.2 in c:\users\lenovo\anaconda3\lib\site-packages (from autograd>=1.3->autogluon.core==0.3.1->autogluon) (0.18.2)
# Requirement already satisfied: plotly in c:\users\lenovo\anaconda3\lib\site-packages (from catboost<0.26,>=0.24.0->autogluon.tabular[all]==0.3.1->autogluon) (5.4.0)
# Requirement already satisfied: six in c:\users\lenovo\anaconda3\lib\site-packages (from catboost<0.26,>=0.24.0->autogluon.tabular[all]==0.3.1->autogluon) (1.16.0)
# Requirement already satisfied: kaggle in c:\users\lenovo\anaconda3\lib\site-packages (from d8<1.0,>=0.0.2->autogluon.vision==0.3.1->autogluon) (1.5.12)
# Requirement already satisfied: xxhash in c:\users\lenovo\anaconda3\lib\site-packages (from d8<1.0,>=0.0.2->autogluon.vision==0.3.1->autogluon) (2.0.2)
# Requirement already satisfied: pyyaml in c:\users\lenovo\anaconda3\lib\site-packages (from dask>=2.6.0->autogluon.core==0.3.1->autogluon) (6.0)
# Requirement already satisfied: fsspec>=0.6.0 in c:\users\lenovo\anaconda3\lib\site-packages (from dask>=2.6.0->autogluon.core==0.3.1->autogluon) (2022.3.0)
# Requirement already satisfied: toolz>=0.8.2 in c:\users\lenovo\anaconda3\lib\site-packages (from dask>=2.6.0->autogluon.core==0.3.1->autogluon) (0.11.2)
# Requirement already satisfied: partd>=0.3.10 in c:\users\lenovo\anaconda3\lib\site-packages (from dask>=2.6.0->autogluon.core==0.3.1->autogluon) (1.2.0)
# Requirement already satisfied: cloudpickle>=1.1.1 in c:\users\lenovo\anaconda3\lib\site-packages (from dask>=2.6.0->autogluon.core==0.3.1->autogluon) (2.0.0)
# Requirement already satisfied: msgpack>=0.6.0 in c:\users\lenovo\anaconda3\lib\site-packages (from distributed>=2.6.0->autogluon.core==0.3.1->autogluon) (1.0.3)
# Requirement already satisfied: zict>=0.1.3 in c:\users\lenovo\anaconda3\lib\site-packages (from distributed>=2.6.0->autogluon.core==0.3.1->autogluon) (2.1.0)
# Requirement already satisfied: sortedcontainers!=2.0.0,!=2.0.1 in c:\users\lenovo\anaconda3\lib\site-packages (from distributed>=2.6.0->autogluon.core==0.3.1->autogluon) (2.4.0)
# Requirement already satisfied: click>=6.6 in c:\users\lenovo\anaconda3\lib\site-packages (from distributed>=2.6.0->autogluon.core==0.3.1->autogluon) (8.0.4)
# Requirement already satisfied: setuptools in c:\users\lenovo\anaconda3\lib\site-packages (from distributed>=2.6.0->autogluon.core==0.3.1->autogluon) (67.7.2)
# Requirement already satisfied: tblib>=1.6.0 in c:\users\lenovo\anaconda3\lib\site-packages (from distributed>=2.6.0->autogluon.core==0.3.1->autogluon) (1.7.0)
# Requirement already satisfied: fastdownload<2,>=0.0.5 in c:\users\lenovo\anaconda3\lib\site-packages (from fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (0.0.5)
# Requirement already satisfied: fastprogress>=0.2.4 in c:\users\lenovo\anaconda3\lib\site-packages (from fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (1.0.0)
# Requirement already satisfied: fastcore<1.4,>=1.3.22 in c:\users\lenovo\anaconda3\lib\site-packages (from fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (1.3.27)
# Requirement already satisfied: torchvision>=0.8.2 in c:\users\lenovo\anaconda3\lib\site-packages (from fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (0.11.1)
# Requirement already satisfied: pip in c:\users\lenovo\anaconda3\lib\site-packages (from fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (22.1.2)
# Requirement already satisfied: spacy<4 in c:\users\lenovo\anaconda3\lib\site-packages (from fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (3.2.0)
# Requirement already satisfied: packaging in c:\users\lenovo\anaconda3\lib\site-packages (from fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (21.3)
# Requirement already satisfied: portalocker in c:\users\lenovo\anaconda3\lib\site-packages (from gluoncv<0.10.5,>=0.10.4->autogluon.extra==0.3.1->autogluon) (2.3.2)
# Requirement already satisfied: autocfg in c:\users\lenovo\anaconda3\lib\site-packages (from gluoncv<0.10.5,>=0.10.4->autogluon.extra==0.3.1->autogluon) (0.0.8)
# Requirement already satisfied: opencv-python in c:\users\lenovo\anaconda3\lib\site-packages (from gluoncv<0.10.5,>=0.10.4->autogluon.extra==0.3.1->autogluon) (4.5.4.60)
# Requirement already satisfied: wheel in c:\users\lenovo\anaconda3\lib\site-packages (from lightgbm<4.0,>=3.0->autogluon.tabular[all]==0.3.1->autogluon) (0.40.0)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\lenovo\anaconda3\lib\site-packages (from networkx<3.0,>=2.3->autogluon.tabular[all]==0.3.1->autogluon) (5.1.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\lenovo\anaconda3\lib\site-packages (from pandas<2.0,>=1.0.0->autogluon.core==0.3.1->autogluon) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\lenovo\anaconda3\lib\site-packages (from pandas<2.0,>=1.0.0->autogluon.core==0.3.1->autogluon) (2022.1)
# Requirement already satisfied: cryptography>=2.5 in c:\users\lenovo\anaconda3\lib\site-packages (from paramiko>=2.4->autogluon.core==0.3.1->autogluon) (37.0.1)
# Requirement already satisfied: bcrypt>=3.1.3 in c:\users\lenovo\anaconda3\lib\site-packages (from paramiko>=2.4->autogluon.core==0.3.1->autogluon) (3.2.0)
# Requirement already satisfied: pynacl>=1.0.1 in c:\users\lenovo\anaconda3\lib\site-packages (from paramiko>=2.4->autogluon.core==0.3.1->autogluon) (1.5.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\lenovo\anaconda3\lib\site-packages (from scikit-learn<0.25,>=0.23.2->autogluon.core==0.3.1->autogluon) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\lenovo\anaconda3\lib\site-packages (from scikit-learn<0.25,>=0.23.2->autogluon.core==0.3.1->autogluon) (1.0.1)
# Requirement already satisfied: typing-extensions in c:\users\lenovo\anaconda3\lib\site-packages (from torch<2.0,>=1.0->autogluon.tabular[all]==0.3.1->autogluon) (4.3.0)
# Requirement already satisfied: colorama in c:\users\lenovo\anaconda3\lib\site-packages (from tqdm>=4.38.0->autogluon.core==0.3.1->autogluon) (0.4.5)
# Requirement already satisfied: s3transfer<0.6.0,>=0.5.0 in c:\users\lenovo\anaconda3\lib\site-packages (from boto3->autogluon.core==0.3.1->autogluon) (0.5.0)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in c:\users\lenovo\anaconda3\lib\site-packages (from boto3->autogluon.core==0.3.1->autogluon) (0.10.0)
# Requirement already satisfied: botocore<1.24.0,>=1.23.10 in c:\users\lenovo\anaconda3\lib\site-packages (from boto3->autogluon.core==0.3.1->autogluon) (1.23.10)
# Requirement already satisfied: cycler>=0.10 in c:\users\lenovo\anaconda3\lib\site-packages (from matplotlib->autogluon.core==0.3.1->autogluon) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\lenovo\anaconda3\lib\site-packages (from matplotlib->autogluon.core==0.3.1->autogluon) (1.4.2)
# Requirement already satisfied: minio in c:\users\lenovo\anaconda3\lib\site-packages (from openml->autogluon.extra==0.3.1->autogluon) (7.1.1)
# Requirement already satisfied: xmltodict in c:\users\lenovo\anaconda3\lib\site-packages (from openml->autogluon.extra==0.3.1->autogluon) (0.12.0)
# Requirement already satisfied: liac-arff>=2.4.0 in c:\users\lenovo\anaconda3\lib\site-packages (from openml->autogluon.extra==0.3.1->autogluon) (2.5.0)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\lenovo\anaconda3\lib\site-packages (from pytest->autogluon.extra==0.3.1->autogluon) (21.4.0)
# Requirement already satisfied: iniconfig in c:\users\lenovo\anaconda3\lib\site-packages (from pytest->autogluon.extra==0.3.1->autogluon) (1.1.1)
# Requirement already satisfied: pluggy<2.0,>=0.12 in c:\users\lenovo\anaconda3\lib\site-packages (from pytest->autogluon.extra==0.3.1->autogluon) (1.0.0)
# Requirement already satisfied: py>=1.8.2 in c:\users\lenovo\anaconda3\lib\site-packages (from pytest->autogluon.extra==0.3.1->autogluon) (1.11.0)
# Requirement already satisfied: tomli>=1.0.0 in c:\users\lenovo\anaconda3\lib\site-packages (from pytest->autogluon.extra==0.3.1->autogluon) (2.0.1)
# Requirement already satisfied: atomicwrites>=1.0 in c:\users\lenovo\anaconda3\lib\site-packages (from pytest->autogluon.extra==0.3.1->autogluon) (1.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lenovo\anaconda3\lib\site-packages (from requests->autogluon.core==0.3.1->autogluon) (2.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lenovo\anaconda3\lib\site-packages (from requests->autogluon.core==0.3.1->autogluon) (1.26.15)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lenovo\anaconda3\lib\site-packages (from requests->autogluon.core==0.3.1->autogluon) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lenovo\anaconda3\lib\site-packages (from requests->autogluon.core==0.3.1->autogluon) (2022.12.7)
# Requirement already satisfied: cffi>=1.1 in c:\users\lenovo\anaconda3\lib\site-packages (from bcrypt>=3.1.3->paramiko>=2.4->autogluon.core==0.3.1->autogluon) (1.15.1)
# Requirement already satisfied: locket in c:\users\lenovo\anaconda3\lib\site-packages (from partd>=0.3.10->dask>=2.6.0->autogluon.core==0.3.1->autogluon) (1.0.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\lenovo\anaconda3\lib\site-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (1.0.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\lenovo\anaconda3\lib\site-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (3.0.6)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in c:\users\lenovo\anaconda3\lib\site-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (0.7.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in c:\users\lenovo\anaconda3\lib\site-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (3.0.8)
# Requirement already satisfied: pathy>=0.3.5 in c:\users\lenovo\anaconda3\lib\site-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (0.6.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\lenovo\anaconda3\lib\site-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (2.0.6)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in c:\users\lenovo\anaconda3\lib\site-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (1.8.2)
# Requirement already satisfied: jinja2 in c:\users\lenovo\anaconda3\lib\site-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (2.11.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\lenovo\anaconda3\lib\site-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (2.0.6)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\lenovo\anaconda3\lib\site-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (3.3.0)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in c:\users\lenovo\anaconda3\lib\site-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (8.0.13)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in c:\users\lenovo\anaconda3\lib\site-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (2.4.2)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in c:\users\lenovo\anaconda3\lib\site-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (0.8.2)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in c:\users\lenovo\anaconda3\lib\site-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (0.4.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\lenovo\anaconda3\lib\site-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (1.0.6)
# Requirement already satisfied: heapdict in c:\users\lenovo\anaconda3\lib\site-packages (from zict>=0.1.3->distributed>=2.6.0->autogluon.core==0.3.1->autogluon) (1.0.1)
# Requirement already satisfied: immutables>=0.9 in c:\users\lenovo\anaconda3\lib\site-packages (from contextvars->autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (0.16)
# Requirement already satisfied: pycodestyle<2.8.0,>=2.7.0 in c:\users\lenovo\anaconda3\lib\site-packages (from flake8->autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (2.7.0)
# Requirement already satisfied: pyflakes<2.4.0,>=2.3.0 in c:\users\lenovo\anaconda3\lib\site-packages (from flake8->autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (2.3.1)
# Requirement already satisfied: mccabe<0.7.0,>=0.6.0 in c:\users\lenovo\anaconda3\lib\site-packages (from flake8->autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (0.6.1)
# Requirement already satisfied: python-slugify in c:\users\lenovo\anaconda3\lib\site-packages (from kaggle->d8<1.0,>=0.0.2->autogluon.vision==0.3.1->autogluon) (5.0.2)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\lenovo\anaconda3\lib\site-packages (from plotly->catboost<0.26,>=0.24.0->autogluon.tabular[all]==0.3.1->autogluon) (8.0.1)
# Requirement already satisfied: pywin32>=226 in c:\users\lenovo\anaconda3\lib\site-packages (from portalocker->gluoncv<0.10.5,>=0.10.4->autogluon.extra==0.3.1->autogluon) (302)
# Requirement already satisfied: tabulate>=0.8.9 in c:\users\lenovo\anaconda3\lib\site-packages (from sacrebleu->autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (0.8.9)
# Requirement already satisfied: pycparser in c:\users\lenovo\anaconda3\lib\site-packages (from cffi>=1.1->bcrypt>=3.1.3->paramiko>=2.4->autogluon.core==0.3.1->autogluon) (2.21)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in c:\users\lenovo\anaconda3\lib\site-packages (from pathy>=0.3.5->spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (5.2.1)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\lenovo\anaconda3\lib\site-packages (from jinja2->spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (2.0.1)
# Requirement already satisfied: text-unidecode>=1.3 in c:\users\lenovo\anaconda3\lib\site-packages (from python-slugify->kaggle->d8<1.0,>=0.0.2->autogluon.vision==0.3.1->autogluon) (1.3)

# %%
import numpy as np
import pandas as pd
from sklearn import datasets
from sklearn.metrics import r2_score, accuracy_score
from sklearn.model_selection import train_test_split
from autogluon.tabular import TabularDataset, TabularPredictor

# %% [markdown]
# ## AutoGluon Classifier

# %%
# Load in the wine dataset
wine = datasets.load_wine()

# %%
# Create the wine `data` dataset as a dataframe and name the columns with `feature_names`
df = pd.DataFrame(wine['data'], columns=wine['feature_names'])

# Include the target as well
df['target'] = wine['target']

# %%
# Split your data with these ratios: train: 0.8 | test: 0.2
df_train, df_test = train_test_split(df, test_size=0.2, random_state= 0)

# %%
# How does the model perform on the training dataset and default model parameters?
# Using the hyperparameters in the requirements, is there improvement?
# Remember we use the test dataset to score the model
# No need to explicitly say this is a classifier, autogluon will pick it up
predictor = TabularPredictor(label='target').fit(
    train_data= df_train, time_limit = 120, presets= "best_quality")
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20230515_121443\"
# Presets specified: ['best_quality']
# Beginning AutoGluon training ... Time limit = 120s
# AutoGluon will save models to "AutogluonModels/ag-20230515_121443\"
# AutoGluon Version:  0.3.1
# Train Data Rows:    142
# Train Data Columns: 13
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'multiclass' (because dtype of label-column == int, but few unique label-values observed).
# 	3 unique label values:  [2, 1, 0]
# 	If 'multiclass' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Note: NumExpr detected 12 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# NumExpr defaulting to 8 threads.
# Train Data Class Count: 3
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    8955.59 MB
# 	Train Data (Original)  Memory Usage: 0.01 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 13 | ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', []) : 13 | ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', ...]
# 	0.0s = Fit runtime
# 	13 features in original data used to generate 13 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.01 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.03s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric argument of fit()
# Fitting 13 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 119.97s of the 119.97s of remaining time.
# 	0.662	 = Validation score   (accuracy)
# 	0.0s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 119.94s of the 119.94s of remaining time.
# 	0.7113	 = Validation score   (accuracy)
# 	0.0s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 119.92s of the 119.92s of remaining time.
# No improvement since epoch 5: early stopping
# No improvement since epoch 3: early stopping
# No improvement since epoch 2: early stopping
# No improvement since epoch 6: early stopping
# No improvement since epoch 7: early stopping
# 	0.9859	 = Validation score   (accuracy)
# 	3.86s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 115.96s of the 115.96s of remaining time.
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# 	0.9859	 = Validation score   (accuracy)
# 	0.82s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 115.14s of the 115.14s of remaining time.
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# 	0.9789	 = Validation score   (accuracy)
# 	0.53s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 114.56s of the 114.56s of remaining time.
# 	0.9859	 = Validation score   (accuracy)
# 	0.25s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 114.26s of the 114.26s of remaining time.
# 	0.9789	 = Validation score   (accuracy)
# 	0.2s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 114.02s of the 114.02s of remaining time.
# 	0.9718	 = Validation score   (accuracy)
# 	1.08s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 112.94s of the 112.94s of remaining time.
# 	Warning: Exception caused ExtraTreesGini_BAG_L1 to fail during training... Skipping this model.
# 		float division by zero
# Detailed Traceback:
# Traceback (most recent call last):
#   File "C:\Users\lenovo\anaconda3\lib\site-packages\autogluon\tabular\trainer\abstract_trainer.py", line 962, in _train_and_save
#     model = self._train_single(X, y, model, X_val, y_val, **model_fit_kwargs)
#   File "C:\Users\lenovo\anaconda3\lib\site-packages\autogluon\tabular\trainer\abstract_trainer.py", line 934, in _train_single
#     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, **model_fit_kwargs)
#   File "C:\Users\lenovo\anaconda3\lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 522, in fit
#     out = self._fit(**kwargs)
#   File "C:\Users\lenovo\anaconda3\lib\site-packages\autogluon\core\models\ensemble\stacker_ensemble_model.py", line 153, in _fit
#     return super()._fit(X=X, y=y, time_limit=time_limit, **kwargs)
#   File "C:\Users\lenovo\anaconda3\lib\site-packages\autogluon\core\models\ensemble\bagged_ensemble_model.py", line 176, in _fit
#     self._fit_single(X=X, y=y, model_base=model_base, use_child_oof=use_child_oof, **kwargs)
#   File "C:\Users\lenovo\anaconda3\lib\site-packages\autogluon\core\models\ensemble\bagged_ensemble_model.py", line 272, in _fit_single
#     model_base.fit(X=X, y=y, time_limit=time_limit, **kwargs)
#   File "C:\Users\lenovo\anaconda3\lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 522, in fit
#     out = self._fit(**kwargs)
#   File "C:\Users\lenovo\anaconda3\lib\site-packages\autogluon\tabular\models\rf\rf_model.py", line 175, in _fit
#     n_estimators_time = math.floor((time_limit - time_train_start + time_start) * n_estimators / time_elapsed)
# ZeroDivisionError: float division by zero
# Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 112.91s of the 112.91s of remaining time.
# 	0.9789	 = Validation score   (accuracy)
# 	0.2s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 112.69s of the 112.69s of remaining time.
# 	0.9718	 = Validation score   (accuracy)
# 	0.52s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: NeuralNetMXNet_BAG_L1 ... Training model for up to 112.03s of the 112.03s of remaining time.
# 	0.9789	 = Validation score   (accuracy)
# 	3.65s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 108.33s of the 108.33s of remaining time.
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# 	0.9789	 = Validation score   (accuracy)
# 	1.04s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Repeating k-fold bagging: 2/20
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 107.25s of the 107.25s of remaining time.
# No improvement since epoch 3: early stopping
# No improvement since epoch 3: early stopping
# No improvement since epoch 2: early stopping
# No improvement since epoch 3: early stopping
# No improvement since epoch 3: early stopping
# 	0.9789	 = Validation score   (accuracy)
# 	6.45s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 104.53s of the 104.53s of remaining time.
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# 	0.9789	 = Validation score   (accuracy)
# 	1.29s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 104.03s of the 104.03s of remaining time.
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# 	0.9718	 = Validation score   (accuracy)
# 	1.01s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 103.52s of the 103.52s of remaining time.
# 	0.9859	 = Validation score   (accuracy)
# 	1.62s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 102.96s of the 102.96s of remaining time.
# 	0.9789	 = Validation score   (accuracy)
# 	0.96s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: NeuralNetMXNet_BAG_L1 ... Training model for up to 102.42s of the 102.42s of remaining time.
# 	0.9718	 = Validation score   (accuracy)
# 	12.74s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 93.25s of the 93.25s of remaining time.
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# 	0.9577	 = Validation score   (accuracy)
# 	2.28s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Repeating k-fold bagging: 3/20
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 91.97s of the 91.97s of remaining time.
# No improvement since epoch 2: early stopping
# No improvement since epoch 6: early stopping
# No improvement since epoch 4: early stopping
# No improvement since epoch 3: early stopping
# 	0.9789	 = Validation score   (accuracy)
# 	9.2s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 89.11s of the 89.11s of remaining time.
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# 	0.9718	 = Validation score   (accuracy)
# 	1.88s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 88.47s of the 88.47s of remaining time.
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# 	0.9789	 = Validation score   (accuracy)
# 	1.66s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 87.8s of the 87.8s of remaining time.
# 	0.9859	 = Validation score   (accuracy)
# 	2.49s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 86.89s of the 86.89s of remaining time.
# 	0.9718	 = Validation score   (accuracy)
# 	1.44s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: NeuralNetMXNet_BAG_L1 ... Training model for up to 86.3s of the 86.3s of remaining time.
# 	0.9789	 = Validation score   (accuracy)
# 	20.96s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 77.96s of the 77.96s of remaining time.
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# 	0.9648	 = Validation score   (accuracy)
# 	3.55s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Repeating k-fold bagging: 4/20
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 76.62s of the 76.62s of remaining time.
# No improvement since epoch 1: early stopping
# No improvement since epoch 7: early stopping
# No improvement since epoch 1: early stopping
# No improvement since epoch 4: early stopping
# 	0.9789	 = Validation score   (accuracy)
# 	11.94s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 73.8s of the 73.8s of remaining time.
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# 	0.9789	 = Validation score   (accuracy)
# 	2.52s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 73.13s of the 73.13s of remaining time.
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# 	0.9789	 = Validation score   (accuracy)
# 	2.31s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 72.48s of the 72.48s of remaining time.
# 	0.9789	 = Validation score   (accuracy)
# 	3.29s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 71.63s of the 71.63s of remaining time.
# 	0.9648	 = Validation score   (accuracy)
# 	1.92s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: NeuralNetMXNet_BAG_L1 ... Training model for up to 71.05s of the 71.05s of remaining time.
# 	0.9789	 = Validation score   (accuracy)
# 	30.14s	 = Training   runtime
# 	0.24s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 61.76s of the 61.76s of remaining time.
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# 	0.9648	 = Validation score   (accuracy)
# 	4.93s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Repeating k-fold bagging: 5/20
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 60.31s of the 60.31s of remaining time.
# No improvement since epoch 5: early stopping
# No improvement since epoch 2: early stopping
# No improvement since epoch 5: early stopping
# No improvement since epoch 5: early stopping
# 	0.9789	 = Validation score   (accuracy)
# 	14.89s	 = Training   runtime
# 	0.2s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 57.29s of the 57.29s of remaining time.
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# 	0.9789	 = Validation score   (accuracy)
# 	3.17s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 56.61s of the 56.61s of remaining time.
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# 	0.993	 = Validation score   (accuracy)
# 	3.03s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 55.82s of the 55.82s of remaining time.
# 	0.9789	 = Validation score   (accuracy)
# 	4.21s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 54.89s of the 54.89s of remaining time.
# 	0.9577	 = Validation score   (accuracy)
# 	2.44s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: NeuralNetMXNet_BAG_L1 ... Training model for up to 54.25s of the 54.25s of remaining time.
# 	0.9789	 = Validation score   (accuracy)
# 	39.93s	 = Training   runtime
# 	0.32s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 44.31s of the 44.31s of remaining time.
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# 	0.9648	 = Validation score   (accuracy)
# 	6.21s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Repeating k-fold bagging: 6/20
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 42.96s of the 42.96s of remaining time.
# No improvement since epoch 6: early stopping
# No improvement since epoch 8: early stopping
# No improvement since epoch 9: early stopping
# No improvement since epoch 3: early stopping
# No improvement since epoch 3: early stopping
# 	0.9859	 = Validation score   (accuracy)
# 	17.83s	 = Training   runtime
# 	0.24s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 39.92s of the 39.92s of remaining time.
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# 	0.9789	 = Validation score   (accuracy)
# 	3.84s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 39.24s of the 39.24s of remaining time.
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# 	0.993	 = Validation score   (accuracy)
# 	3.71s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 38.52s of the 38.52s of remaining time.
# 	0.9859	 = Validation score   (accuracy)
# 	4.87s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 37.84s of the 37.84s of remaining time.
# 	0.9577	 = Validation score   (accuracy)
# 	2.94s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: NeuralNetMXNet_BAG_L1 ... Training model for up to 37.22s of the 37.22s of remaining time.
# 	0.9789	 = Validation score   (accuracy)
# 	50.04s	 = Training   runtime
# 	0.39s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 26.99s of the 26.99s of remaining time.
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# 	0.9648	 = Validation score   (accuracy)
# 	7.65s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Repeating k-fold bagging: 7/20
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 25.51s of the 25.51s of remaining time.
# No improvement since epoch 1: early stopping
# No improvement since epoch 2: early stopping
# No improvement since epoch 1: early stopping
# No improvement since epoch 6: early stopping
# No improvement since epoch 4: early stopping
# 	0.9789	 = Validation score   (accuracy)
# 	20.5s	 = Training   runtime
# 	0.29s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 22.71s of the 22.71s of remaining time.
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# 	0.9789	 = Validation score   (accuracy)
# 	4.52s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 21.98s of the 21.98s of remaining time.
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# 	0.9859	 = Validation score   (accuracy)
# 	4.41s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 21.25s of the 21.25s of remaining time.
# 	0.9859	 = Validation score   (accuracy)
# 	5.8s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 20.31s of the 20.31s of remaining time.
# 	0.9718	 = Validation score   (accuracy)
# 	3.48s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting model: NeuralNetMXNet_BAG_L1 ... Training model for up to 19.66s of the 19.66s of remaining time.
# 	0.9789	 = Validation score   (accuracy)
# 	60.92s	 = Training   runtime
# 	0.45s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 8.65s of the 8.65s of remaining time.
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# 	0.9648	 = Validation score   (accuracy)
# 	8.99s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Completed 7/20 k-fold bagging repeats ...
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 119.97s of the 7.26s of remaining time.
# 	0.993	 = Validation score   (accuracy)
# 	0.2s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 112.95s ...
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20230515_121443\")

# %%
# Output the fit summary of the training run
predictor.fit_summary()
# Out:
# *** Summary of fit() ***
# Estimated performance of each model:
#                       model  score_val  pred_time_val   fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0       WeightedEnsemble_L2   0.992958       0.135060  10.410510                0.000000           0.203109            2       True         13
# 1   RandomForestGini_BAG_L1   0.985915       0.015621   0.249942                0.015621           0.249942            1       True          6
# 2           CatBoost_BAG_L1   0.985915       0.036136   5.801014                0.036136           5.801014            1       True          8
# 3           LightGBM_BAG_L1   0.985915       0.098923   4.406388                0.098923           4.406388            1       True          5
# 4     ExtraTreesEntr_BAG_L1   0.978873       0.015620   0.203077                0.015620           0.203077            1       True          9
# 5   RandomForestEntr_BAG_L1   0.978873       0.019641   0.203063                0.019641           0.203063            1       True          7
# 6         LightGBMXT_BAG_L1   0.978873       0.039664   4.521169                0.039664           4.521169            1       True          4
# 7    NeuralNetFastAI_BAG_L1   0.978873       0.293786  20.496193                0.293786          20.496193            1       True          3
# 8     NeuralNetMXNet_BAG_L1   0.978873       0.453155  60.915058                0.453155          60.915058            1       True         11
# 9            XGBoost_BAG_L1   0.971831       0.143932   3.484021                0.143932           3.484021            1       True         10
# 10     LightGBMLarge_BAG_L1   0.964789       0.106782   8.986408                0.106782           8.986408            1       True         12
# 11    KNeighborsDist_BAG_L1   0.711268       0.015621   0.000000                0.015621           0.000000            1       True          2
# 12    KNeighborsUnif_BAG_L1   0.661972       0.000000   0.000000                0.000000           0.000000            1       True          1
# Number of models trained: 13
# Types of models trained:
# {'StackerEnsembleModel_KNN', 'StackerEnsembleModel_LGB', 'StackerEnsembleModel_RF', 'WeightedEnsembleModel', 'StackerEnsembleModel_CatBoost', 'StackerEnsembleModel_XGBoost', 'StackerEnsembleModel_TabularNeuralNet', 'StackerEnsembleModel_NNFastAiTabular', 'StackerEnsembleModel_XT'}
# Bagging used: True  (with 5 folds)
# Multi-layer stack-ensembling used: False
# Feature Metadata (Processed):
# (raw dtype, special dtypes):
# ('float', []) : 13 | ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', ...]
# Plot summary of models saved to file: AutogluonModels/ag-20230515_121443\SummaryOfModels.html
# *** End of fit() summary ***
# {'model_types': {'KNeighborsUnif_BAG_L1': 'StackerEnsembleModel_KNN',
#   'KNeighborsDist_BAG_L1': 'StackerEnsembleModel_KNN',
#   'NeuralNetFastAI_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'LightGBMXT_BAG_L1': 'StackerEnsembleModel_LGB',
#   'LightGBM_BAG_L1': 'StackerEnsembleModel_LGB',
#   'RandomForestGini_BAG_L1': 'StackerEnsembleModel_RF',
#   'RandomForestEntr_BAG_L1': 'StackerEnsembleModel_RF',
#   'CatBoost_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'ExtraTreesEntr_BAG_L1': 'StackerEnsembleModel_XT',
#   'XGBoost_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'NeuralNetMXNet_BAG_L1': 'StackerEnsembleModel_TabularNeuralNet',
#   'LightGBMLarge_BAG_L1': 'StackerEnsembleModel_LGB',
#   'WeightedEnsemble_L2': 'WeightedEnsembleModel'},
#  'model_performance': {'KNeighborsUnif_BAG_L1': 0.6619718309859155,
#   'KNeighborsDist_BAG_L1': 0.7112676056338029,
#   'NeuralNetFastAI_BAG_L1': 0.9788732394366197,
#   'LightGBMXT_BAG_L1': 0.9788732394366197,
#   'LightGBM_BAG_L1': 0.9859154929577465,
#   'RandomForestGini_BAG_L1': 0.9859154929577465,
#   'RandomForestEntr_BAG_L1': 0.9788732394366197,
#   'CatBoost_BAG_L1': 0.9859154929577465,
#   'ExtraTreesEntr_BAG_L1': 0.9788732394366197,
#   'XGBoost_BAG_L1': 0.971830985915493,
#   'NeuralNetMXNet_BAG_L1': 0.9788732394366197,
#   'LightGBMLarge_BAG_L1': 0.9647887323943662,
#   'WeightedEnsemble_L2': 0.9929577464788732},
#  'model_best': 'WeightedEnsemble_L2',
#  'model_paths': {'KNeighborsUnif_BAG_L1': 'AutogluonModels/ag-20230515_121443\\models\\KNeighborsUnif_BAG_L1\\',
#   'KNeighborsDist_BAG_L1': 'AutogluonModels/ag-20230515_121443\\models\\KNeighborsDist_BAG_L1\\',
#   'NeuralNetFastAI_BAG_L1': 'AutogluonModels/ag-20230515_121443\\models\\NeuralNetFastAI_BAG_L1\\',
#   'LightGBMXT_BAG_L1': 'AutogluonModels/ag-20230515_121443\\models\\LightGBMXT_BAG_L1\\',
#   'LightGBM_BAG_L1': 'AutogluonModels/ag-20230515_121443\\models\\LightGBM_BAG_L1\\',
#   'RandomForestGini_BAG_L1': 'AutogluonModels/ag-20230515_121443\\models\\RandomForestGini_BAG_L1\\',
#   'RandomForestEntr_BAG_L1': 'AutogluonModels/ag-20230515_121443\\models\\RandomForestEntr_BAG_L1\\',
#   'CatBoost_BAG_L1': 'AutogluonModels/ag-20230515_121443\\models\\CatBoost_BAG_L1\\',
#   'ExtraTreesEntr_BAG_L1': 'AutogluonModels/ag-20230515_121443\\models\\ExtraTreesEntr_BAG_L1\\',
#   'XGBoost_BAG_L1': 'AutogluonModels/ag-20230515_121443\\models\\XGBoost_BAG_L1\\',
#   'NeuralNetMXNet_BAG_L1': 'AutogluonModels/ag-20230515_121443\\models\\NeuralNetMXNet_BAG_L1\\',
#   'LightGBMLarge_BAG_L1': 'AutogluonModels/ag-20230515_121443\\models\\LightGBMLarge_BAG_L1\\',
#   'WeightedEnsemble_L2': 'AutogluonModels/ag-20230515_121443\\models\\WeightedEnsemble_L2\\'},
#  'model_fit_times': {'KNeighborsUnif_BAG_L1': 0.0,
#   'KNeighborsDist_BAG_L1': 0.0,
#   'NeuralNetFastAI_BAG_L1': 20.496192932128906,
#   'LightGBMXT_BAG_L1': 4.5211687088012695,
#   'LightGBM_BAG_L1': 4.4063880443573,
#   'RandomForestGini_BAG_L1': 0.24994206428527832,
#   'RandomForestEntr_BAG_L1': 0.2030634880065918,
#   'CatBoost_BAG_L1': 5.801013708114624,
#   'ExtraTreesEntr_BAG_L1': 0.2030773162841797,
#   'XGBoost_BAG_L1': 3.484020948410034,
#   'NeuralNetMXNet_BAG_L1': 60.91505765914917,
#   'LightGBMLarge_BAG_L1': 8.986408233642578,
#   'WeightedEnsemble_L2': 0.203108549118042},
#  'model_pred_times': {'KNeighborsUnif_BAG_L1': 0.0,
#   'KNeighborsDist_BAG_L1': 0.015621423721313477,
#   'NeuralNetFastAI_BAG_L1': 0.29378628730773926,
#   'LightGBMXT_BAG_L1': 0.03966355323791504,
#   'LightGBM_BAG_L1': 0.0989232063293457,
#   'RandomForestGini_BAG_L1': 0.015621423721313477,
#   'RandomForestEntr_BAG_L1': 0.019641399383544922,
#   'CatBoost_BAG_L1': 0.03613638877868652,
#   'ExtraTreesEntr_BAG_L1': 0.01562047004699707,
#   'XGBoost_BAG_L1': 0.14393186569213867,
#   'NeuralNetMXNet_BAG_L1': 0.4531548023223877,
#   'LightGBMLarge_BAG_L1': 0.1067817211151123,
#   'WeightedEnsemble_L2': 0.0},
#  'num_bag_folds': 5,
#  'max_stack_level': 2,
#  'num_classes': 3,
#  'model_hyperparams': {'KNeighborsUnif_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'KNeighborsDist_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetFastAI_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBMXT_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForestGini_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'RandomForestEntr_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTreesEntr_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'XGBoost_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetMXNet_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBMLarge_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'WeightedEnsemble_L2': {'use_orig_features': False,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True}},
#  'leaderboard':                       model  score_val  pred_time_val   fit_time  \
#  0       WeightedEnsemble_L2   0.992958       0.135060  10.410510
#  1   RandomForestGini_BAG_L1   0.985915       0.015621   0.249942
#  2           CatBoost_BAG_L1   0.985915       0.036136   5.801014
#  3           LightGBM_BAG_L1   0.985915       0.098923   4.406388
#  4     ExtraTreesEntr_BAG_L1   0.978873       0.015620   0.203077
#  5   RandomForestEntr_BAG_L1   0.978873       0.019641   0.203063
#  6         LightGBMXT_BAG_L1   0.978873       0.039664   4.521169
#  7    NeuralNetFastAI_BAG_L1   0.978873       0.293786  20.496193
#  8     NeuralNetMXNet_BAG_L1   0.978873       0.453155  60.915058
#  9            XGBoost_BAG_L1   0.971831       0.143932   3.484021
#  10     LightGBMLarge_BAG_L1   0.964789       0.106782   8.986408
#  11    KNeighborsDist_BAG_L1   0.711268       0.015621   0.000000
#  12    KNeighborsUnif_BAG_L1   0.661972       0.000000   0.000000
#
#      pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
#  0                 0.000000           0.203109            2       True
#  1                 0.015621           0.249942            1       True
#  2                 0.036136           5.801014            1       True
#  3                 0.098923           4.406388            1       True
#  4                 0.015620           0.203077            1       True
#  5                 0.019641           0.203063            1       True
#  6                 0.039664           4.521169            1       True
#  7                 0.293786          20.496193            1       True
#  8                 0.453155          60.915058            1       True
#  9                 0.143932           3.484021            1       True
#  10                0.106782           8.986408            1       True
#  11                0.015621           0.000000            1       True
#  12                0.000000           0.000000            1       True
#
#      fit_order
#  0          13
#  1           6
#  2           8
#  3           5
#  4           9
#  5           7
#  6           4
#  7           3
#  8          11
#  9          10
#  10         12
#  11          2
#  12          1  }

# %%
predictor.leaderboard(silent=True).plot(kind='bar', x='model', y='score_val')
# Out:
# <AxesSubplot:xlabel='model'>

# %%
# Evaluate the models performance on the test dataset
performance = predictor.evaluate(df_test)
# Out:
# Evaluation: accuracy on test data: 0.9444444444444444
# Evaluations on test data:
# {
#     "accuracy": 0.9444444444444444,
#     "balanced_accuracy": 0.9583333333333334,
#     "mcc": 0.9156002315160504
# }

# %% [markdown]
# ## AutoGluon Regression

# %%
# Load in the diabetes dataset
diabetes = datasets.load_diabetes()

# %%
# Create the diabetes `data` dataset as a dataframe and name the columns with `feature_names`
dfd = pd.DataFrame(diabetes['data'], columns=diabetes['feature_names'])

# Include the target as well
dfd['target'] = diabetes['target']

# %%
# Split your data with these ratios: train: 0.8 | test: 0.2
dfd_train, dfd_test = train_test_split(dfd, test_size=0.2, random_state=0)

# %%
# How does the model perform on the training dataset and default model parameters?
# Using the hyperparameters in the requirements, is there improvement?
# Remember we use the test dataset to score the model
# No need to explicitly say this is a regression, autogluon will pick it up
predictor = TabularPredictor(label='target', problem_type='regression', eval_metric='r2'
                            ).fit(train_data= dfd,time_limit=120,presets="best_quality")
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20230515_122008\"
# Presets specified: ['best_quality']
# Beginning AutoGluon training ... Time limit = 120s
# AutoGluon will save models to "AutogluonModels/ag-20230515_122008\"
# AutoGluon Version:  0.3.1
# Train Data Rows:    442
# Train Data Columns: 10
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    8740.78 MB
# 	Train Data (Original)  Memory Usage: 0.04 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 1 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 10 | ['age', 'sex', 'bmi', 'bp', 's1', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     : 9 | ['age', 'bmi', 'bp', 's1', 's2', ...]
# 		('int', ['bool']) : 1 | ['sex']
# 	0.0s = Fit runtime
# 	10 features in original data used to generate 10 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.03 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.02s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'r2'
# 	To change this, specify the eval_metric argument of fit()
# Fitting 11 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 119.98s of the 119.98s of remaining time.
# 	0.3761	 = Validation score   (r2)
# 	0.0s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 119.96s of the 119.96s of remaining time.
# 	0.3843	 = Validation score   (r2)
# 	0.02s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 119.94s of the 119.94s of remaining time.
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# 	0.4934	 = Validation score   (r2)
# 	1.36s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 118.51s of the 118.51s of remaining time.
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\lenovo\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# 	0.4431	 = Validation score   (r2)
# 	1.25s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ... Training model for up to 117.23s of the 117.23s of remaining time.
# 	0.4257	 = Validation score   (r2)
# 	0.23s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 116.95s of the 116.94s of remaining time.
# 	0.4734	 = Validation score   (r2)
# 	1.48s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L1 ... Training model for up to 115.42s of the 115.42s of remaining time.
# 	0.4701	 = Validation score   (r2)
# 	0.18s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 115.19s of the 115.19s of remaining time.
# 	0.4608	 = Validation score   (r2)
# 	1.98s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 113.1s of the 113.1s of remaining time.
# 	0.3768	 = Validation score   (r2)
# 	1.44s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetMXNet_BAG_L1 ... Training model for up to 111.42s of the 111.42s of remaining time.

# %%
# Output the fit summary of the training run
predictor.fit_summary()

# %%
predictor.leaderboard(silent= True).plot(kind='bar', x="model", y="score_val")

# %%
# Evaluate the models performance on the test dataset
performance = predictor.evaluate(dfd_test)
